# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
census = pd.read_csv('census.csv',
                  na_values = ':',
                  usecols = [ 'census_year', 'state_fips_code', 'age',
                              'sex', 'race_general', 'marital_status', 'total_personal_income'])
census
# Out:
#      census_year state_fips_code  age     sex     race_general  \
# 0           2000         Florida   44    Male  Two major races
# 1           2000         Florida   20  Female            White
# 2           2000         Florida   20    Male            Black
# 3           2000         Florida    6  Female            White
# 4           2000         Florida   55    Male            White
# 5           2000         Florida   43  Female            White
# 6           2000         Florida   60  Female            White
# 7           2000         Florida   47  Female            White
# 8           2000         Florida   54  Female            Black
# 9           2000         Florida   58  Female            White
# 10          2000         Florida   33  Female            White
# 11          2000         Florida   51  Female            White
# 12          2000         Florida   62  Female            White
# 13          2000         Florida    8    Male            White
# ...

# %%
census['marital_status']
# Out:
# 0      Married/spouse present
# 1        Never married/single
# 2        Never married/single
# 3        Never married/single
# 4      Married/spouse present
# 5      Married/spouse present
# 6      Married/spouse present
# 7      Married/spouse present
# 8      Married/spouse present
# 9                     Widowed
# 10       Never married/single
# 11                   Divorced
# 12                   Divorced
# 13       Never married/single
# 14       Never married/single
# 15     Married/spouse present
# 16     Married/spouse present
# 17       Never married/single
# 18     Married/spouse present
# 19     Married/spouse present
# 20     Married/spouse present
# 21                    Widowed
# 22       Never married/single
# 23       Never married/single
# 24       Never married/single
# 25     Married/spouse present
# 26       Never married/single
# 27                    Widowed
# 28       Never married/single
# 29                   Divorced
#                 ...
# ...

# %%
census[census['marital_status'] == 'Widowed']
# Out:
#      census_year state_fips_code  age     sex  \
# 9           2000         Florida   58  Female
# 21          2000         Florida   80  Female
# 27          2000         Florida   67    Male
# 39          2000        New York   82  Female
# 42          2000        New York   83    Male
# 74          2000        New York   81    Male
# 76          2000        New York   72  Female
# 106         2000      California   58  Female
# 138         2000      California   79  Female
# 210         2000            Ohio   50  Female
# 216         2000            Ohio   75  Female
# 266         2000           Texas   52  Female
# 267         2000           Texas   70    Male
# 287         2000        Kentucky   60    Male
# 290         2000   Massachusetts   82  Female
# 320         2000         Arizona   60  Female
# 321         2000         Arizona   67  Female
# 326         2000        Delaware   85  Female
# 342         2000         Georgia   59  Female
# ...

# %%
census[census['marital_status'] == 'Divorced']
# Out:
#      census_year state_fips_code  age     sex     race_general marital_status  \
# 11          2000         Florida   51  Female            White       Divorced
# 12          2000         Florida   62  Female            White       Divorced
# 29          2000         Florida   69  Female            White       Divorced
# 40          2000        New York   46  Female            White       Divorced
# 57          2000        New York   40  Female  Two major races       Divorced
# 66          2000        New York   61  Female            White       Divorced
# 85          2000         Alabama   73  Female            Black       Divorced
# 87          2000         Alabama   60  Female            Black       Divorced
# 101         2000      California   52  Female            White       Divorced
# 108         2000      California   20    Male            White       Divorced
# 119         2000      California   58    Male            Other       Divorced
# ...

# %%
census[census['marital_status'] == 'Never married/single']
# Out:
#      census_year state_fips_code  age     sex race_general  \
# 1           2000         Florida   20  Female        White
# 2           2000         Florida   20    Male        Black
# 3           2000         Florida    6  Female        White
# 10          2000         Florida   33  Female        White
# 13          2000         Florida    8    Male        White
# 14          2000         Florida   25    Male        White
# 17          2000         Florida    1    Male        White
# 22          2000         Florida    2    Male        White
# 23          2000         Florida   47    Male        White
# 24          2000         Florida   12    Male        White
# 26          2000         Florida    8  Female        White
# 28          2000         Florida   17  Female        White
# 31          2000         Florida   18  Female        White
# 34          2000         Florida   21    Male        Black
# 36          2000         Florida   18    Male        White
# ...

# %%
census[census['marital_status'] == 'Married/spouse absent']
# Out:
#      census_year state_fips_code  age     sex race_general  \
# 104         2000      California   21  Female        Other
# 166         2000        Illinois   39    Male        White
# 167         2000        Illinois   87  Female        White
# 177         2000        Maryland   25    Male        Black
# 250         2000           Texas   49    Male        Black
# 273         2000        Colorado   35    Male        Other
# 286         2000        Kentucky   37    Male        Black
# 319         2000         Arizona   53  Female        White
# 332         2000         Georgia   40    Male        Black
# 339         2000         Georgia   28  Female        Black
# 432         2000         Indiana   57  Female        White
# 443         2000       Louisiana   44    Male        Black
# 473         2000    Pennsylvania   36    Male        Black
# 498         2000        Virginia   60    Male        Black
#
#             marital_status  total_personal_income
# ...

# %%
census[census['marital_status'] == 'Married/spouse present']
# Out:
#      census_year state_fips_code  age     sex  \
# 0           2000         Florida   44    Male
# 4           2000         Florida   55    Male
# 5           2000         Florida   43  Female
# 6           2000         Florida   60  Female
# 7           2000         Florida   47  Female
# 8           2000         Florida   54  Female
# 15          2000         Florida   44  Female
# 16          2000         Florida   28  Female
# 18          2000         Florida   31    Male
# 19          2000         Florida   69  Female
# 20          2000         Florida   31    Male
# 25          2000         Florida   47    Male
# 30          2000         Florida   55    Male
# 32          2000         Florida   66  Female
# 33          2000         Florida   58  Female
# 35          2000         Florida   52    Male
# 38          2000         Florida   26    Male
# 41          2000        New York   63    Male
# 43          2000        New York   35  Female
# ...
