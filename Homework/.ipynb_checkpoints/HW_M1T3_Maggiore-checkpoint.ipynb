# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Question 1
# When appending new rows to a dataframe, what do the parameters 'ignore_index' and 'sort' do?
#
# ignore_index=True ‘ignores’. It outputs data together in the order that they are passed, then reassigns a range for the actual index.
# The sort () method sorts the list ascending by default.

# %% [markdown]
# # Question 2
# The columns of this datafram are shown below. They are cenus_year, state_fips_code, total_family_income, age, sex, race_general, marital_status, and total_personal_income.

# %% [markdown]
# # Question 3

# %%
census = pd.read_csv('census.csv',
                  na_values = ':',
                  usecols = [ 'census_year', 'state_fips_code','total_family_income', 'age', 'sex',
                             'race_general','marital_status','total_personal_income'])
census
# Out:
#      census_year state_fips_code  total_family_income  age     sex  \
# 0           2000         Florida              14550.0   44    Male
# 1           2000         Florida              22800.0   20  Female
# 2           2000         Florida                  0.0   20    Male
# 3           2000         Florida              23000.0    6  Female
# 4           2000         Florida              48000.0   55    Male
# 5           2000         Florida              74000.0   43  Female
# 6           2000         Florida              23000.0   60  Female
# 7           2000         Florida              74000.0   47  Female
# 8           2000         Florida              60000.0   54  Female
# 9           2000         Florida              14600.0   58  Female
# 10          2000         Florida                  0.0   33  Female
# 11          2000         Florida              37000.0   51  Female
# 12          2000         Florida              32000.0   62  Female
# ...

# %%
census[19:46]
# Out:
#     census_year state_fips_code  total_family_income  age     sex  \
# 19         2000         Florida              43950.0   69  Female
# 20         2000         Florida              49000.0   31    Male
# 21         2000         Florida              31600.0   80  Female
# 22         2000         Florida              50090.0    2    Male
# 23         2000         Florida              64800.0   47    Male
# 24         2000         Florida              90000.0   12    Male
# 25         2000         Florida              38320.0   47    Male
# 26         2000         Florida             103700.0    8  Female
# 27         2000         Florida                  0.0   67    Male
# 28         2000         Florida              70700.0   17  Female
# 29         2000         Florida              64800.0   69  Female
# 30         2000         Florida              60000.0   55    Male
# 31         2000         Florida             118100.0   18  Female
# ...

# %%
census[23:27][['age', 'sex', 'race_general']]
# Out:
#     age     sex race_general
# 23   47    Male        White
# 24   12    Male        White
# 25   47    Male        White
# 26    8  Female        White

# %%
census[45:46]
# Out:
#     census_year state_fips_code  total_family_income  age     sex  \
# 45         2000        New York              68020.0    2  Female
#
#    race_general        marital_status  total_personal_income
# 45      Chinese  Never married/single                    NaN

# %%
census[['census_year', 'state_fips_code']]
# Out:
#      census_year state_fips_code
# 0           2000         Florida
# 1           2000         Florida
# 2           2000         Florida
# 3           2000         Florida
# 4           2000         Florida
# 5           2000         Florida
# 6           2000         Florida
# 7           2000         Florida
# 8           2000         Florida
# 9           2000         Florida
# 10          2000         Florida
# 11          2000         Florida
# 12          2000         Florida
# 13          2000         Florida
# 14          2000         Florida
# 15          2000         Florida
# 16          2000         Florida
# 17          2000         Florida
# 18          2000         Florida
# 19          2000         Florida
# 20          2000         Florida
# 21          2000         Florida
# 22          2000         Florida
# 23          2000         Florida
# 24          2000         Florida
# 25          2000         Florida
# 26          2000         Florida
# ...

# %% [markdown]
# # Question 4

# %%
age2 = census['age']
age2
# Out:
# 0      44
# 1      20
# 2      20
# 3       6
# 4      55
# 5      43
# 6      60
# 7      47
# 8      54
# 9      58
# 10     33
# 11     51
# 12     62
# 13      8
# 14     25
# 15     44
# 16     28
# 17      1
# 18     31
# 19     69
# 20     31
# 21     80
# 22      2
# 23     47
# 24     12
# 25     47
# 26      8
# 27     67
# 28     17
# 29     69
#        ..
# 470     1
# 471    29
# 472    61
# 473    36
# 474    25
# 475    41
# 476     9
# 477    10
# 478    13
# 479     3
# 480    15
# 481    32
# 482    68
# 483    32
# 484    32
# 485    24
# 486    18
# 487    41
# 488     6
# 489    38
# 490    43
# 491    76
# 492    24
# 493    36
# 494     5
# 495    68
# 496    12
# 497    60
# 498    60
# 499    47
# Name: age, Length: 500, dtype: int64

# %% [markdown]
# # Question 5

# %% [markdown]
# *COMMENT: We wanted to add two new rows to the census dataframe with the year column removed 2/4pts*

# %%
new_rows_dict = {
    'favorite_color' : ['Pink','Yellow' , 'Green'],
    'favorite_food' : ['Salad', 'Pizza', 'Tacos'],
    'sex' : ['Female', 'Male', 'Female'] 
}
new_rows_df = pd.DataFrame(new_rows_dict)

new_rows_df
# Out:
#   favorite_color favorite_food     sex
# 0           Pink         Salad  Female
# 1         Yellow         Pizza    Male
# 2          Green         Tacos  Female

# %% [markdown]
# # Question 6

# %%
census[census['state_fips_code'] == 'Connecticut']
# Out:
#      census_year state_fips_code  total_family_income  age     sex  \
# 274         2000     Connecticut                  NaN   56  Female
# 275         2000     Connecticut                  0.0   52    Male
# 276         2000     Connecticut              80100.0   16    Male
# 277         2000     Connecticut             129300.0   32  Female
#
#     race_general          marital_status  total_personal_income
# 274        Black    Never married/single                 3600.0
# 275        White                Divorced                51000.0
# 276        White    Never married/single                    0.0
# 277        White  Married/spouse present                34300.0

# %%
census[(census['total_family_income'] < 75000)]
# Out:
#      census_year state_fips_code  total_family_income  age     sex  \
# 0           2000         Florida              14550.0   44    Male
# 1           2000         Florida              22800.0   20  Female
# 2           2000         Florida                  0.0   20    Male
# 3           2000         Florida              23000.0    6  Female
# 4           2000         Florida              48000.0   55    Male
# 5           2000         Florida              74000.0   43  Female
# 6           2000         Florida              23000.0   60  Female
# 7           2000         Florida              74000.0   47  Female
# 8           2000         Florida              60000.0   54  Female
# 9           2000         Florida              14600.0   58  Female
# 10          2000         Florida                  0.0   33  Female
# 11          2000         Florida              37000.0   51  Female
# 12          2000         Florida              32000.0   62  Female
# ...

# %%
census[(census['age'] >= 30) & (census['age'] <= 50)]
# Out:
#      census_year state_fips_code  total_family_income  age     sex  \
# 0           2000         Florida              14550.0   44    Male
# 5           2000         Florida              74000.0   43  Female
# 7           2000         Florida              74000.0   47  Female
# 10          2000         Florida                  0.0   33  Female
# 15          2000         Florida             100100.0   44  Female
# 18          2000         Florida              57200.0   31    Male
# 20          2000         Florida              49000.0   31    Male
# 23          2000         Florida              64800.0   47    Male
# 25          2000         Florida              38320.0   47    Male
# 40          2000        New York                  0.0   46  Female
# 43          2000        New York              48630.0   35  Female
# 47          2000        New York                  0.0   36    Male
# 55          2000        New York              37100.0   33    Male
# ...

# %%
census[(census['race_general'] == 'White') | (census['race_general'] == 'Black')]
# Out:
#      census_year state_fips_code  total_family_income  age     sex  \
# 1           2000         Florida              22800.0   20  Female
# 2           2000         Florida                  0.0   20    Male
# 3           2000         Florida              23000.0    6  Female
# 4           2000         Florida              48000.0   55    Male
# 5           2000         Florida              74000.0   43  Female
# 6           2000         Florida              23000.0   60  Female
# 7           2000         Florida              74000.0   47  Female
# 8           2000         Florida              60000.0   54  Female
# 9           2000         Florida              14600.0   58  Female
# 10          2000         Florida                  0.0   33  Female
# 11          2000         Florida              37000.0   51  Female
# 12          2000         Florida              32000.0   62  Female
# 13          2000         Florida             113000.0    8    Male
# ...

# %% [markdown]
# # Question 7

# %%
census[census['total_personal_income'].isnull() ]
# Out:
#      census_year state_fips_code  total_family_income  age     sex  \
# 3           2000         Florida              23000.0    6  Female
# 13          2000         Florida             113000.0    8    Male
# 17          2000         Florida              48000.0    1    Male
# 22          2000         Florida              50090.0    2    Male
# 24          2000         Florida              90000.0   12    Male
# 26          2000         Florida             103700.0    8  Female
# 37          2000         Florida               6000.0    2    Male
# 44          2000        New York              13000.0    1    Male
# 45          2000        New York              68020.0    2  Female
# 49          2000        New York              12400.0    7    Male
# 51          2000        New York              65000.0    1  Female
# 54          2000        New York              81710.0   14    Male
# 59          2000        New York             168200.0    6  Female
# ...

# %% [markdown]
# # Question 8

# %%
census.isnull()
# Out:
#      census_year  state_fips_code  total_family_income    age    sex  \
# 0          False            False                False  False  False
# 1          False            False                False  False  False
# 2          False            False                False  False  False
# 3          False            False                False  False  False
# 4          False            False                False  False  False
# 5          False            False                False  False  False
# 6          False            False                False  False  False
# 7          False            False                False  False  False
# 8          False            False                False  False  False
# 9          False            False                False  False  False
# 10         False            False                False  False  False
# 11         False            False                False  False  False
# 12         False            False                False  False  False
# ...

# %% [markdown]
# Observations on what I see in that output in Question 8 is that isnull() basically searched every output in every row, and 'false' was outputted if it wasn't empty, and 'true' was outputted if it was empty. Being that it searched the census dataframe as a whole compared to a specifc row, every single part was tested to be empty or not. Very interesting.
